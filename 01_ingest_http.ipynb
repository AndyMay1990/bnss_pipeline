# %%
import inspect
import bnss_pipeline.models as m

print("models.py path:", m.__file__)
print("RawDocument fields:", list(m.RawDocument.model_fields.keys()))
print("RawDocument source head:\n", inspect.getsource(m.RawDocument)[:300])
# Out:
# models.py path: c:\bnss_pipeline\bnss_pipeline\models.py
# RawDocument fields: ['source_url', 'fetched_at', 'status', 'headers', 'as_of', 'content_hash', 'raw_html_path', 'raw_meta_path', 'etag', 'last_modified', 'cached_content_hash', 'error']
# RawDocument source head:
#  class RawDocument(BaseModel):
#     source_url: str
#     fetched_at: datetime
#     status: int
#     headers: Dict[str, Any] = Field(default_factory=dict)
#     as_of: Optional[str] = None
#
#     content_hash: Optional[str] = None
#     raw_html_path: Optional[str] = None
#     raw_meta_path: Optional[str] = None

# %%
from bnss_pipeline.config import get_settings
from bnss_pipeline.ingest_http import fetch_many

s = get_settings()
urls = [s.cytrain_index_bnss, s.cytrain_section_table_bnss]
urls
# Out:
# ['https://cytrain.ncrb.gov.in/staticpage/web_pages/IndexBNSS.html',
#  'https://cytrain.ncrb.gov.in/staticpage/web_pages/SectionTableBNSS.html']

# %%
results = fetch_many(urls, as_of="2026-01-10")
[(r.source_url, r.status, r.content_hash or r.cached_content_hash) for r in results]
# Out:
# [('https://cytrain.ncrb.gov.in/staticpage/web_pages/IndexBNSS.html',
#   200,
#   '175496c89bef7a90dd9972bc62ecb38fbff5387a8d8485a55e09ec8baace22c1'),
#  ('https://cytrain.ncrb.gov.in/staticpage/web_pages/SectionTableBNSS.html',
#   200,
#   '14e5248872740078841aa14ab129b6180fb74339f84183a41195bacbf936be87')]
